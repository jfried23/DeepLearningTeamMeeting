# %%
import keras
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <h4> MNIST Dataset</h4>
#
# <p>
#     Keras conviently provides the classic
#     <a href='https://en.wikipedia.org/wiki/MNIST_database'>mnist dataset</a>
#     by simple function call. MNIST is a collection of greyscale images of handwritten digits (0-9). Our task will be to build a classifier that can 'read' these pictures of handwritten inputs and guess the corresponding numerical representation. Before doing anything fancy lets load in the data and take a look.
# </p>

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
#Let's plot 16 random images and their answers

#Select random images
select_images = np.random.randint(0, y_train.shape[0], 16)

#plot them

fig, axes = plt.subplots(nrows=4, ncols=4)

for i, ax in zip(select_images,axes.flatten()):
    ax.imshow(x_train[i], cmap=plt.cm.binary)
    ax.set_title(y_train[i])
    ax.xaxis.set_visible(False) ; ax.yaxis.set_visible(False)
plt.tight_layout()

# %% [markdown]
# <h5>Simple Feed forward Neural Network</h5>

# %% [markdown]
# <p>Layers in a feed foward Neural Network are really just matrix multiplications. Shapes matter in matrix multiplication, so we need to first define the shapes of our inputs and outputs to each layer. </p>
# <p>The MNIST dataset consits of 28x28 dimensional images, so first lets define an Input layer that takes a 28 x 28 dimensional arrays for each training example. See doccumentation in <b>keras.layers.Input</b> for details on how to construct this input layer.</p>

# %%
#Create an input layer here
input_tensor = keras.layers.Input( shape=x_train.shape[1:] )

# %% [markdown]
# <p>Our input layer returns a computational tensor. You can think of this tensor as being a variable or placeholder representing (N x 28 x 28) dimensional input where N is the batch size. We will use this input to construct a computational graph, that through basic algrabreic manipulation, will eventually transform our (N x 28 x 28) dimensional input into a (Nx10) output of predictions.</p>
#
# <p>As a first exercise, lets implement logistic regression using keras! We will be using the functional programming style to implement our model. In this style of programig we instantiate and call a Layer  <a href='https://en.wikipedia.org/wiki/Function_object'>functor object</a> (found in the path keras.layers)  like so:
#
#     <center>new_tensor = keras.layers.LayerObject1( \*\*args )(<b><i>input_tensor</i></b> )</center>
# </p>
#
# <p>The output tensor of this transformation can undergo further transformations by passing it additional Layer functors like so:
#     <p>
#     <center>output = keras.layers.LayerObject2( \*\*args )( <b><i>new_tensor</i></b> )</center></p>
# </p>
# <p>
# For logisitic regression we will use 3 layer types:
# <ol>
#     <li><b>keras.layers.Flatten</b> -- to first transform our (Nx28x28) inputs into (N x 784) outputs.</li>
#     <li><b>keras.layers.BatchNormalization</b> -- to standardize all our inputs to have unit norm and standard deviation.
#     </li>
#     <li><b>keras.layers.Dense</b> -- to apply the matrix multiplication that will learn the best matrix of weights for converting an (N x 784) dimensional matrix into a (N x 10) dimensional array of outputs. (Considering the rules of linear algebra, how many weights dose this layer need to 'learn'?) </li>
# </ol>
# As a convience the keras.layers.Dense object accepts the keyword argument <i>activation</i> that will apply the desired activation function to the layer outputs. Keras built in activation functions can be found under <b>keras.activations</b>. For logistic regression we use the <a href='https://en.wikipedia.org/wiki/Softmax_function'>softmax activation function</a>. Try implenting this feed forward NN using keras doccumention for the three layer objects we listed above.
# </p>

# %%
#Implement the layer feed forward NN outlined above, below:
x     = keras.layers.Flatten()(input_tensor)
x     = keras.layers.BatchNormalization(axis=-1)(x)
x     = keras.layers.Dense(10,activation=keras.activations.softmax)(x)

# %% [markdown]
# To turn this sequence of transformational steps on variable tensors into a data processing pipline that will learn from and transform actual data, we need to create and compile a keras model object. The keras module object constructor takes a list of tensor objects as inputs and a list of tensor objects that will be the model output as outputs. We will instantiate our model and print a summary below:

# %%
model = keras.models.Model(inputs=[input_tensor], outputs=[x])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_31 (InputLayer)        (None, 28, 28)            0
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 784)               0
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 784)               3136
# _________________________________________________________________
# dense_51 (Dense)             (None, 10)                7850
# =================================================================
# Total params: 10,986
# Trainable params: 9,418
# Non-trainable params: 1,568
# _________________________________________________________________

# %% [markdown]
# Now we will compile our keras model using the Model mebmer function <i>compile</i>. As arguments, compilation takes:
#
# <ol>
# <li>A keras optimizer object that will preform the gradient descent. See keras.optimizers . (ADAM is good general choice.) </li>
# <li>A loss function (or dictionary of loss functions) the optimizer will seek to minimize. See keras.losses</li>
# <li>A metric or list of metrics (optional) for monitoring how the model preforms during training. See keras.metrics</li>
# </ol>

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss = keras.losses.categorical_crossentropy,
              metrics=[keras.metrics.categorical_accuracy]
             )

# %%
history = model.fit(
                x=x_train, 
                y=keras.utils.to_categorical(y_train), 
                batch_size=1000,
                epochs=10,
                validation_data=(x_test, keras.utils.to_categorical(y_test)),
                verbose=0
            )

# %%
plt.figure(figsize=(10,5))

plt.subplot(121)
plt.plot(history.epoch, history.history['loss'], label='Training Loss')
plt.plot(history.epoch, history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.ylabel('Log Loss')
plt.xlabel('Epoch')
plt.title('Training & Validation Loss')


plt.subplot(122)
plt.plot(history.epoch, history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(history.epoch, history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Training & Validation Accuracy')

plt.show()

# %%
#Use trained model to generate predictions for all test set images
predictions = model.predict(x_test)

# %% [markdown]
# <h2>Lets Take A Closer Look</h2>

# %%
def visualize_preformance(x, guess, true, indx):
    plt.subplot(121)
    plt.bar(range(10),guess[indx])
    plt.xticks([v for v in range(10)])
    plt.ylabel('Probability')
    plt.title( "Prediction: %i" %(np.argmax(guess[indx])) )

    plt.subplot(122)
    plt.title("True value: %i"%(true[indx]))
    plt.imshow(x[indx], cmap=plt.cm.binary)
    plt.xticks([]); plt.yticks([])

# %% [markdown]
# <h5>Look At One We Got Right</h5>

# %%
correct = np.argwhere( np.argmax(predictions,axis=1) == y_test).flatten()
indx = np.random.choice(correct)

visualize_preformance(x_test, predictions,y_test, indx)

# %% [markdown]
# <h5>Now Look At A Randomly Selected Mistake</h5>

# %%
wrong = np.argwhere( np.argmax(predictions,axis=1) != y_test).flatten()
indx = np.random.choice(wrong)

visualize_preformance(x_test, predictions,y_test, indx)

# %% [markdown]
# <h2>Convolutional Neural Network</h2>

# %%
image = keras.layers.Input( shape=x_train.shape[1:] )

x = keras.layers.Reshape((28,28,1))(image)

x = keras.layers.BatchNormalization(axis=-1)(x)

x = keras.layers.Conv2D(16,(5,5),padding='valid', activation=keras.activations.relu)(x)
x = keras.layers.MaxPool2D(pool_size=(2,2),padding='valid')(x)
x = keras.layers.BatchNormalization(axis=-1)(x)
x = keras.layers.Dropout(0.5)(x)

x = keras.layers.Flatten()(x)
x = keras.layers.BatchNormalization(axis=-1)(x)
x = keras.layers.Dropout(0.5)(x)

x = keras.layers.Dense(1024, activation=keras.activations.relu)(x)
x = keras.layers.BatchNormalization(axis=-1)(x)
x = keras.layers.Dropout(0.5)(x)

x = keras.layers.Dense(10, activation=keras.activations.softmax)(x)

# %%
model=keras.models.Model(inputs=[image], outputs=[x])

model.compile(optimizer=keras.optimizers.Adam(),
              loss = keras.losses.categorical_crossentropy,
              metrics=[keras.metrics.categorical_accuracy]
             )

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_30 (InputLayer)        (None, 28, 28)            0
# _________________________________________________________________
# reshape_17 (Reshape)         (None, 28, 28, 1)         0
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 28, 28, 1)         4
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 24, 24, 16)        416
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 12, 12, 16)        0
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 12, 12, 16)        64
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 12, 12, 16)        0
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 2304)              9216
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 2304)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 1024)              2360320
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_50 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 2,384,366
# Trainable params: 2,377,676
# Non-trainable params: 6,690
# _________________________________________________________________

# %%
history = model.fit(
                x=x_train, 
                y=keras.utils.to_categorical(y_train), 
                batch_size=1000,
                epochs=15,
                validation_data=(x_test, keras.utils.to_categorical(y_test)),
                verbose=1
            )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 34s 573us/step - loss: 0.6003 - categorical_accuracy: 0.8420 - val_loss: 0.4850 - val_categorical_accuracy: 0.8286
# Epoch 2/15
# 60000/60000 [==============================] - 31s 511us/step - loss: 0.2485 - categorical_accuracy: 0.9257 - val_loss: 0.2218 - val_categorical_accuracy: 0.9437
# Epoch 3/15
# 60000/60000 [==============================] - 30s 504us/step - loss: 0.1854 - categorical_accuracy: 0.9415 - val_loss: 0.1610 - val_categorical_accuracy: 0.9667
# Epoch 4/15
# 60000/60000 [==============================] - 33s 556us/step - loss: 0.1529 - categorical_accuracy: 0.9522 - val_loss: 0.1307 - val_categorical_accuracy: 0.9713
# Epoch 5/15
# 60000/60000 [==============================] - 32s 530us/step - loss: 0.1340 - categorical_accuracy: 0.9576 - val_loss: 0.0981 - val_categorical_accuracy: 0.9747
# Epoch 6/15
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.1217 - categorical_accuracy: 0.9610 - val_loss: 0.0733 - val_categorical_accuracy: 0.9810
# Epoch 7/15
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.1131 - categorical_accuracy: 0.9640 - val_loss: 0.0552 - val_categorical_accuracy: 0.9842
# Epoch 8/15
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.1047 - categorical_accuracy: 0.9665 - val_loss: 0.0461 - val_categorical_accuracy: 0.9865
# Epoch 9/15
# 60000/60000 [==============================] - 30s 502us/step - loss: 0.0979 - categorical_accuracy: 0.9689 - val_loss: 0.0423 - val_categorical_accuracy: 0.9859
# Epoch 10/15
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0896 - categorical_accuracy: 0.9713 - val_loss: 0.0385 - val_categorical_accuracy: 0.9875
# Epoch 11/15
# 60000/60000 [==============================] - 30s 502us/step - loss: 0.0871 - categorical_accuracy: 0.9718 - val_loss: 0.0353 - val_categorical_accuracy: 0.9875
# Epoch 12/15
# 60000/60000 [==============================] - 30s 502us/step - loss: 0.0860 - categorical_accuracy: 0.9726 - val_loss: 0.0328 - val_categorical_accuracy: 0.9894
# Epoch 13/15
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0820 - categorical_accuracy: 0.9734 - val_loss: 0.0331 - val_categorical_accuracy: 0.9884
# Epoch 14/15
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0771 - categorical_accuracy: 0.9753 - val_loss: 0.0320 - val_categorical_accuracy: 0.9885
# Epoch 15/15
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0721 - categorical_accuracy: 0.9770 - val_loss: 0.0295 - val_categorical_accuracy: 0.9895

# %%
plt.figure(figsize=(10,5))

plt.subplot(121)
plt.plot(history.epoch, history.history['loss'], label='Training Loss')
plt.plot(history.epoch, history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.ylabel('Log Loss')
plt.xlabel('Epoch')
plt.title('Training & Validation Loss')


plt.subplot(122)
plt.plot(history.epoch, history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(history.epoch, history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Training & Validation Accuracy')

plt.show()

# %% [markdown]
# Not bad, certinly beats 92% we were getting with the dense layer! Lets try decreasing the learning rate.

# %%
model.optimizer.lr = .1*model.optimizer.lr

history2 = model.fit(
                x=x_train, 
                y=keras.utils.to_categorical(y_train), 
                batch_size=1000,
                epochs=10,
                validation_data=(x_test, keras.utils.to_categorical(y_test)),
                verbose=1
            )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 31s 509us/step - loss: 0.0727 - categorical_accuracy: 0.9762 - val_loss: 0.0298 - val_categorical_accuracy: 0.9890
# Epoch 2/10
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0685 - categorical_accuracy: 0.9772 - val_loss: 0.0300 - val_categorical_accuracy: 0.9893
# Epoch 3/10
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0667 - categorical_accuracy: 0.9784 - val_loss: 0.0284 - val_categorical_accuracy: 0.9889
# Epoch 4/10
# 60000/60000 [==============================] - 31s 508us/step - loss: 0.0648 - categorical_accuracy: 0.9787 - val_loss: 0.0286 - val_categorical_accuracy: 0.9897
# Epoch 5/10
# 60000/60000 [==============================] - 30s 507us/step - loss: 0.0621 - categorical_accuracy: 0.9796 - val_loss: 0.0280 - val_categorical_accuracy: 0.9903
# Epoch 6/10
# 60000/60000 [==============================] - 30s 504us/step - loss: 0.0624 - categorical_accuracy: 0.9797 - val_loss: 0.0271 - val_categorical_accuracy: 0.9907
# Epoch 7/10
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0613 - categorical_accuracy: 0.9801 - val_loss: 0.0273 - val_categorical_accuracy: 0.9914
# Epoch 8/10
# 60000/60000 [==============================] - 30s 503us/step - loss: 0.0574 - categorical_accuracy: 0.9815 - val_loss: 0.0270 - val_categorical_accuracy: 0.9899
# Epoch 9/10
# 60000/60000 [==============================] - 30s 505us/step - loss: 0.0575 - categorical_accuracy: 0.9809 - val_loss: 0.0262 - val_categorical_accuracy: 0.9913
# Epoch 10/10
# 60000/60000 [==============================] - 30s 504us/step - loss: 0.0540 - categorical_accuracy: 0.9822 - val_loss: 0.0262 - val_categorical_accuracy: 0.9909

# %%
vg16=keras.applications.VGG16?

# %%
vg16=keras.applications.VGG16(include_top=False)

# %%
vg16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_33 (InputLayer)        (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
